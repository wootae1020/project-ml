# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import gc

import xgboost as xgb
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Data Load

# %%
# 데이터 분할(폴더) 구분
data_splits = ["train"]

# 각 데이터 유형별 폴더명, 파일 접미사, 변수 접두어 설정
data_categories = {
    "회원정보": {"folder": "1.회원정보", "suffix": "회원정보", "var_prefix": "customer"},
    #"신용정보": {"folder": "2.신용정보", "suffix": "신용정보", "var_prefix": "credit"},
    "승인매출정보": {"folder": "3.승인매출정보", "suffix": "승인매출정보", "var_prefix": "sales"},
    #"청구정보": {"folder": "4.청구입금정보", "suffix": "청구정보", "var_prefix": "billing"},
    #"잔액정보": {"folder": "5.잔액정보", "suffix": "잔액정보", "var_prefix": "balance"},
    #"채널정보": {"folder": "6.채널정보", "suffix": "채널정보", "var_prefix": "channel"},
    #"마케팅정보": {"folder": "7.마케팅정보", "suffix": "마케팅정보", "var_prefix": "marketing"},
    #"성과정보": {"folder": "8.성과정보", "suffix": "성과정보", "var_prefix": "performance"}
}

# 2018년 7월부터 12월까지의 월 리스트
months = ['07', '08', '09', '10', '11', '12']
#months = ['07']

for split in data_splits:
    for category, info in data_categories.items():
        folder = info["folder"]
        suffix = info["suffix"]
        var_prefix = info["var_prefix"]
        
        for month in months:
            # 파일명 형식: 2018{month}_{split}_{suffix}.parquet
            file_path = f"./open/{split}/{folder}/2018{month}_{split}_{suffix}.parquet"
            # 변수명 형식: {var_prefix}_{split}_{month}
            variable_name = f"{var_prefix}_{split}_{month}"
            globals()[variable_name] = pd.read_parquet(file_path)
            print(f"{variable_name} is loaded from {file_path}")

gc.collect()

# %% [markdown]
# # Data Preprocessing(1) : Concat & Merge

# %%
# 데이터 유형별 설정 
info_categories = ["customer", "sales"]
#info_categories = ["customer", "credit", "sales", "billing", "balance", "channel", "marketing", "performance"]

# 월 설정
months = ['07', '08', '09', '10', '11', '12']

# %%
#### Train ####

# 각 유형별로 월별 데이터를 합쳐서 새로운 변수에 저장
train_dfs = {}

for prefix in info_categories:
    # globals()에서 동적 변수명으로 데이터프레임들을 가져와 리스트에 저장
    df_list = [globals()[f"{prefix}_train_{month}"] for month in months]
    train_dfs[f"{prefix}_train_df"] = pd.concat(df_list, axis=0)
    gc.collect()
    print(f"{prefix}_train_df is created with shape: {train_dfs[f'{prefix}_train_df'].shape}")


customer_train_df = train_dfs["customer_train_df"]
#credit_train_df   = train_dfs["credit_train_df"]
sales_train_df    = train_dfs["sales_train_df"]
#billing_train_df  = train_dfs["billing_train_df"]
#balance_train_df  = train_dfs["balance_train_df"]
#channel_train_df  = train_dfs["channel_train_df"]
#marketing_train_df= train_dfs["marketing_train_df"]
#performance_train_df = train_dfs["performance_train_df"]

gc.collect()

# %% [markdown]
# # 저장(최초에는 여기까지 실행하고 그 이후는 밑에부터)

# %%
customer_train_df.to_csv('1merge.csv')
sales_train_df.to_csv('3merge.csv')

# %% [markdown]
# # 불러오기(2번째부터는 여기서부터)

# %%
import pandas as pd
import numpy as np
import gc

import xgboost as xgb
from sklearn.preprocessing import LabelEncoder

# %%
customer_train_df=pd.read_csv('1merge.csv')
sales_train_df=pd.read_csv('3merge.csv')

# %%
#### Train ####

train_df = customer_train_df.merge(sales_train_df, on=['기준년월', 'ID'], how='left')
print("Step1 저장 완료: train_step1, shape:", train_df.shape)
del customer_train_df, sales_train_df
gc.collect()

# %% [markdown]
# # 저장(최초에는 여기까지 실행하고 그 이후는 밑에부터)

# %%
train_df.to_csv('1_3merge.csv')

# %% [markdown]
# # 불러오기(2번째부터는 여기서부터)

# %%
import pandas as pd
import numpy as np
import gc

import xgboost as xgb
from sklearn.preprocessing import LabelEncoder

# %%
train_df=pd.read_csv('1_3merge.csv')
# Out:
# C:\Users\J\AppData\Local\Temp\ipykernel_18688\1154772784.py:1: DtypeWarning: Columns (262) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df=pd.read_csv('1_3merge.csv')

# %% [markdown]
# # 전처리

# %% [markdown]
# ## 결측치 처리

# %%
# 연체일자_B0M → 결측은 0, 값이 있으면 1로 변환 후 삭제 // 3번에 해당하지 않은 컬럼이므로 주석처리
#train_df['연체일자_B0M_여부'] = train_df['연체일자_B0M'].notna().astype(int)
#train_df.drop('연체일자_B0M', axis=1, inplace=True)

# 업종 관련 결측 → '없음'으로 채움
train_df['_3순위여유업종'] = train_df['_3순위여유업종'].fillna('없음')
train_df['_2순위여유업종'] = train_df['_2순위여유업종'].fillna('없음')
train_df['_3순위납부업종'] = train_df['_3순위납부업종'].fillna('없음')
train_df['_3순위교통업종'] = train_df['_3순위교통업종'].fillna('없음')
train_df['_1순위여유업종'] = train_df['_1순위여유업종'].fillna('없음')
train_df['_2순위납부업종'] = train_df['_2순위납부업종'].fillna('없음')

# 최종카드론_대출일자 → 결측은 0, 값이 있으면 1로 변환 후 삭제 // 3번에 해당하지 않은 컬럼이므로 주석처리
#train_df['최종카드론_대출여부'] = train_df['최종카드론_대출일자'].notna().astype(int)
#train_df.drop('최종카드론_대출일자', axis=1, inplace=True)

# 최종카드론 코드 결측 → 0으로 채움
train_df['최종카드론_신청경로코드'] = train_df['최종카드론_신청경로코드'].fillna(0)
train_df['최종카드론_금융상환방식코드'] = train_df['최종카드론_금융상환방식코드'].fillna(0)

# RV신청일자 → 결측은 0, 값이 있으면 1로 변환 후 삭제 // 3번에 해당하지 않은 컬럼이므로 주석처리
#train_df['RV신청여부'] = train_df['RV신청일자'].notna().astype(int)
#train_df.drop('RV신청일자', axis=1, inplace=True)

# 나머지 업종 관련 결측 → '없음'으로 채움
train_df['_2순위교통업종'] = train_df['_2순위교통업종'].fillna('없음')
#train_df['OS구분코드'] = train_df['OS구분코드'].fillna('그외') // 3번에 해당하지 않은 컬럼이므로 주석처리
train_df['_3순위쇼핑업종'] = train_df['_3순위쇼핑업종'].fillna('없음')
train_df['_1순위납부업종'] = train_df['_1순위납부업종'].fillna('없음')
train_df['_1순위교통업종'] = train_df['_1순위교통업종'].fillna('없음')
train_df['_2순위쇼핑업종'] = train_df['_2순위쇼핑업종'].fillna('없음')
train_df['_3순위업종'] = train_df['_3순위업종'].fillna('없음')
train_df['_2순위신용체크구분'] = train_df['_2순위신용체크구분'].fillna('없음')
train_df['_1순위쇼핑업종'] = train_df['_1순위쇼핑업종'].fillna('없음')
train_df['_2순위업종'] = train_df['_2순위업종'].fillna('없음')
train_df['_1순위업종'] = train_df['_1순위업종'].fillna('없음')

# 혜택 관련 결측 → 0으로 채움 // 3번에 해당하지 않은 컬럼이므로 주석처리
#train_df['혜택수혜율_B0M'] = train_df['혜택수혜율_B0M'].fillna(0)
#train_df['혜택수혜율_R3M'] = train_df['혜택수혜율_R3M'].fillna(0)

# 최종유효년월_신용_이용 → 결측은 0, 값이 있으면 1로 변환 후 삭제
train_df['최종유효년월_신용_이용_여부'] = train_df['최종유효년월_신용_이용'].notna().astype(int)
train_df.drop('최종유효년월_신용_이용', axis=1, inplace=True)

# 가입통신회사코드, 직장시도명 → 결측 처리
train_df['가입통신회사코드'] = train_df['가입통신회사코드'].fillna('그외')
train_df['직장시도명'] = train_df['직장시도명'].fillna('없음')

# 최종유효년월_신용_이용가능 → 결측은 0, 값이 있으면 1로 변환 후 삭제
train_df['최종유효년월_신용_이용가능_여부'] = train_df['최종유효년월_신용_이용가능'].notna().astype(int)
train_df.drop('최종유효년월_신용_이용가능', axis=1, inplace=True)

# 최종카드발급일자 → 결측은 0, 값이 있으면 1로 변환 후 삭제
train_df['최종카드발급여부'] = train_df['최종카드발급일자'].notna().astype(int)
train_df.drop('최종카드발급일자', axis=1, inplace=True)

# RV전환가능여부, _1순위신용체크구분 → 결측행 제거 // 3번에 해당하지 않은 컬럼이므로 주석처리
#train_df = train_df.dropna(subset=['RV전환가능여부', '_1순위신용체크구분'])

# %% [markdown]
# ## 기준년월은 datetime type으로 바꾸고 나머지는 10101이라는 값이 있으면 0으로 바꾸고 라벨인코딩하는 코드

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# 기준년월: datetime 변환
train_df['기준년월'] = pd.to_datetime(
    train_df['기준년월'].astype(str).where(train_df['기준년월'].astype(str).str.match(r'^\d{6}$')),
    format='%Y%m',
    errors='coerce'
)
# 날짜 컬럼 리스트 (입회일자 및 최종이용일자 관련)
date_cols = [
    '입회일자_신용', '최종이용일자_기본', '최종이용일자_신판', '최종이용일자_CA',
    '최종이용일자_카드론', '최종이용일자_체크', '최종이용일자_일시불', '최종이용일자_할부'
]
# 10101 이상치 → '0' 문자열로 대체한 후 라벨 인코딩
for col in date_cols:
    # 문자열로 변환하고 이상치 대체
    train_df[col] = train_df[col].astype(str).replace('10101', '0')
    # 라벨 인코딩
    le = LabelEncoder()
    train_df[col] = le.fit_transform(train_df[col])
# 결과 확인 (선택)
print(train_df[date_cols].head())
# Out:
#    입회일자_신용  최종이용일자_기본  최종이용일자_신판  최종이용일자_CA  최종이용일자_카드론  최종이용일자_체크  \
# 0      259       1109       1090       2933           0       1912
# 1      314       1109       1096       2577        1167          0
# 2      202       1096       1083       2920         673        793
# 3      299       1111       1092       2935           0        744
# 4      324        933        920          0           0       2010
#
#    최종이용일자_일시불  최종이용일자_할부
# 0         912       2074
# 1         922       1880
# 2         909       2058
# 3         907       2076
# 4         746          0

# %% [markdown]
# ## 결측치를 0으로 바꾸고 라벨인코딩 하는 코드

# %%
from sklearn.preprocessing import LabelEncoder
# 처리 대상 컬럼 리스트
# 3번에 없는 컬럼들 이므로 이 부분 생략 
label_date_cols = [
    '연체일자_B0M', '최종카드론_대출일자', 'RV신청일자',
    '최종유효년월_신용_이용', '최종유효년월_신용_이용가능', '최종카드발급일자'
]
# 각 컬럼에 대해 결측치 → '0' 대체 후 라벨 인코딩
for col in label_date_cols:
    # NaN → '0' 문자열로 대체
    train_df[col] = train_df[col].fillna(0).astype(int).astype(str)
    # 라벨 인코딩
    le = LabelEncoder()
    train_df[col] = le.fit_transform(train_df[col])
# 결과 예시 출력
print(train_df[label_date_cols].head())

# %% [markdown]
# ## float64지만 범주형처럼 보이는 컬럼 처리

# %%
# 1. 최종카드론_금융상환방식코드: 결측치 0으로 채우고 category로 변환
train_df['최종카드론_금융상환방식코드'] = train_df['최종카드론_금융상환방식코드'].fillna(0).astype('category')

# %% [markdown]
# ## int64지만 범주형처럼 보이는 컬럼 처리

# %%
category_cols = [
    '남녀구분코드', '회원여부_이용가능', '회원여부_이용가능_CA',
    '회원여부_이용가능_카드론', '소지여부_신용', '회원여부_연체',
    '이용거절여부_카드론', '동의여부_한도증액안내', '수신거부여부_TM',
    '수신거부여부_DM', '수신거부여부_메일', '수신거부여부_SMS',
    '마케팅동의여부', '보유여부_해외겸용_본인', '이용가능여부_해외겸용_본인',
    '이용여부_3M_해외겸용_본인', '보유여부_해외겸용_신용_본인',
    '이용가능여부_해외겸용_신용_본인', '이용여부_3M_해외겸용_신용_본인',
    '일시불ONLY전환가능여부', '연체감액여부_R3M', '시장단기연체여부_R6M',
    '시장단기연체여부_R3M', '청구서발송여부_B0', '청구서발송여부_R3M',
    '청구서발송여부_R6M'
]

# %%
from sklearn.preprocessing import LabelEncoder

# 3.승인매출정보 관련 category 컬럼
sales_category_cols = [
    '회원여부_이용가능', '회원여부_이용가능_CA', '회원여부_이용가능_카드론',
    '소지여부_신용', '회원여부_연체', '이용거절여부_카드론',
    '일시불ONLY전환가능여부'
]

# 존재하는 컬럼만 필터링
existing_sales_cols = [col for col in sales_category_cols if col in train_df.columns]

# category 타입으로 변환 후 라벨 인코딩
train_df[existing_sales_cols] = train_df[existing_sales_cols].astype('category')
le = LabelEncoder()
for col in existing_sales_cols:
    train_df[col] = le.fit_transform(train_df[col])

# %%
#지금 해야할 것 
# 라벨인코딩 및 원핫 인코딩
# 연령 : 올인원인코딩
# 가입통신회사코드 : 원핫인코딩
# 거주시도명 : 원핫인코딩
# 직장시도명 : 원핫인코딩
# _1순위신용체크구분 : 원핫인코딩
# _2순위신용체크구분 : 원핫인코딩
# 연회비발생카드수_B0M : 올인원인코딩
# 상품관련면제카드수_B0M : 범주가 하나임
# 임직원면제카드수_B0M : 범주가 하나임
# 우수회원면제카드수_B0M : 범주가 하나임
# 기타면제카드수_B0M : 범주가 하나임
# Life_Stage : 원핫인코딩
# 자발한도감액횟수_R12M : 0회,1회 => 0,1
# 한도증액횟수_R12M : 올인원인코딩
# 카드론동의여부 : 원핫인코딩
# RV전환가능여부 : 원핫인코딩
# 한도심사요청건수 : 올인원인코딩
# _1순위업종 : 원핫인코딩
# _2순위업종', '_3순위업종', '_1순위쇼핑업종', '_2순위쇼핑업종', '_3순위쇼핑업종', '_1순위교통업종', '_2순위교통업종', '_3순위교통업종', '_1순위여유업종', '_2순위여유업종', '_3순위여유업종', '_1순위납부업종', '_2순위납부업종', '_3순위납부업종'
# 최종카드론_신청경로코드 : 원핫인코딩
# 이용금액대 : 올인원인코딩
# 대표결제방법코드 : 범주가 하나임
# 대표청구지고객주소구분코드 : 원핫인코딩
# 대표청구서수령지구분코드 : 원핫인코딩
# 청구서수령방법 : 원핫인코딩
# 할인건수_R3M : 올인원인코딩
# 할인건수_B0M : 올인원인코딩
# 인입횟수_ARS_R6M : 올인원인코딩
# 이용메뉴건수_ARS_R6M : 올인원인코딩
# 방문횟수_PC_R6M : 올인원인코딩
# 방문일수_PC_R6M : 올인원인코딩
# 방문횟수_앱_R6M : 올인원인코딩
# OS구분코드 : 원핫인코딩
# 캠페인접촉건수_R12M : 올인원인코딩
# 캠페인접촉일수_R12M : 올인원인코딩

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# 라벨 인코딩 대상
all_in_one_cols = [
    '연령', '연회비발생카드수_B0M', '한도증액횟수_R12M', '한도심사요청건수',
    '이용금액대', '할인건수_R3M', '할인건수_B0M', '인입횟수_ARS_R6M',
    '이용메뉴건수_ARS_R6M', '방문횟수_PC_R6M', '방문일수_PC_R6M',
    '방문횟수_앱_R6M', '캠페인접촉건수_R12M', '캠페인접촉일수_R12M'
]

le = LabelEncoder()
for col in all_in_one_cols:
    if col in train_df.columns:
        train_df[col] = le.fit_transform(train_df[col].astype(str))

# 0회/1회 변환
if '자발한도감액횟수_R12M' in train_df.columns:
    train_df['자발한도감액횟수_R12M'] = train_df['자발한도감액횟수_R12M'].map({'0회': 0, '1회': 1}).fillna(0).astype(int)

# 제외 대상
excluded_cols = ['상품관련면제카드수_B0M', '임직원면제카드수_B0M', '우수회원면제카드수_B0M', '기타면제카드수_B0M', '대표결제방법코드']

# 원핫 인코딩 대상
onehot_cols = [
    '가입통신회사코드', '거주시도명', '직장시도명', '_1순위신용체크구분', '_2순위신용체크구분',
    'Life_Stage', '카드론동의여부', 'RV전환가능여부', '_1순위업종', '_2순위업종', '_3순위업종',
    '_1순위쇼핑업종', '_2순위쇼핑업종', '_3순위쇼핑업종', '_1순위교통업종', '_2순위교통업종', '_3순위교통업종',
    '_1순위여유업종', '_2순위여유업종', '_3순위여유업종', '_1순위납부업종', '_2순위납부업종', '_3순위납부업종',
    '최종카드론_신청경로코드', '대표청구지고객주소구분코드', '대표청구서수령지구분코드', '청구서수령방법', 'OS구분코드'
]

# 실제 존재하는 컬럼만 필터링
onehot_cols = [col for col in onehot_cols if col in train_df.columns]

# 원핫 인코딩 대상 중 '최종카드론_신청경로코드'가 object 또는 string이 되도록 먼저 변환
train_df['최종카드론_신청경로코드'] = train_df['최종카드론_신청경로코드'].astype(str)

# 다시 실제 존재하는 컬럼만 필터링 (object형으로 존재하면 포함됨)
onehot_cols = [col for col in onehot_cols if col in train_df.columns]

# 원핫 인코딩 재실행
train_df_encoded = pd.get_dummies(train_df, columns=onehot_cols, drop_first=True)

# 결과 확인
print(train_df_encoded.filter(like='최종카드론_신청경로코드').columns)
# Out:
# Index(['최종카드론_신청경로코드_1', '최종카드론_신청경로코드_2', '최종카드론_신청경로코드_7', '최종카드론_신청경로코드_8',
#        '최종카드론_신청경로코드_D'],
#       dtype='object')

# %% [markdown]
# # 다시 저장

# %%
train_df.to_csv('1_3merge_final.csv')
train_df_encoded.to_csv('1_3merge_encoded.csv')

# %% [markdown]
# # 로드

# %%
import pandas as pd
import numpy as np
import gc

import xgboost as xgb
from sklearn.preprocessing import LabelEncoder

# %%
train_df=pd.read_csv('1_3merge_final.csv')
train_df_encoded=pd.read_csv('1_3merge_encoded.csv')

# %% [markdown]
# # 상관관계 구하기(train_cols 수정하면서 하기)

# %%
import pandas as pd

# Segment를 숫자로 변환
train_df['Segment_code'] = train_df['Segment'].astype('category').cat.codes
train_df_encoded['Segment_code'] = train_df['Segment_code']

# 1. 승인매출 정보 컬럼 리스트 (명세서 No.3 ~ No.406 기준)
target_cols = train_df.columns[
    train_df.columns.get_loc("최종이용일자_기본") : train_df.columns.get_loc("이용금액대") + 1
]

# 2-1. 원본 데이터 내 상관계수 (숫자형 변수만)
target_numeric = train_df[target_cols].select_dtypes(include='number').copy()
target_numeric['Segment_code'] = train_df['Segment_code']
corr_sales = target_numeric.corr()['Segment_code'].drop('Segment_code')

# 2-2. 인코딩 데이터 내 상관계수 (승인매출 변수 중 인코딩된 것만)
encoded_target_cols = [col for col in train_df_encoded.columns if col.startswith(tuple(target_cols))]
corr_encoded_sales = train_df_encoded[encoded_target_cols + ['Segment_code']].corr()['Segment_code'].drop('Segment_code')

# 3. 두 결과를 병합하여 비교 테이블 생성
corr_sales_df = corr_sales.rename("원본(train_df)").to_frame()
corr_encoded_df = corr_encoded_sales.rename("인코딩(train_df_encoded)").to_frame()

combined_corr = pd.merge(
    corr_sales_df,
    corr_encoded_df,
    how='outer',
    left_index=True,
    right_index=True
)

# 절댓값 기준 정렬
combined_corr['최대상관계수(절댓값)'] = combined_corr.abs().max(axis=1)
combined_corr = combined_corr.sort_values(by='최대상관계수(절댓값)', ascending=False)

# %%
# pandas 출력 옵션 변경 - 모든 행 보기
pd.set_option('display.max_rows', None)

# 전체 출력
print(combined_corr)
# Out:
#                        원본(train_df)  인코딩(train_df_encoded)  최대상관계수(절댓값)
# 정상청구원금_B5M                -0.660738              -0.660738     0.660738
# 정상청구원금_B0M                -0.634571              -0.634571     0.634571
# 정상청구원금_B2M                -0.628078              -0.628078     0.628078
# 이용금액_일시불_R12M             -0.595858              -0.595858     0.595858
# 이용금액_일시불_B0M              -0.575032              -0.575032     0.575032
# 이용금액_일시불_R6M              -0.568893              -0.568893     0.568893
# 이용금액_일시불_R3M              -0.567357              -0.567357     0.567357
# 이용금액_오프라인_B0M             -0.566186              -0.566186     0.566186
# 정상입금원금_B5M                -0.551228              -0.551228     0.551228
# 정상입금원금_B0M                -0.549280              -0.549280     0.549280
# 이용금액_오프라인_R3M             -0.539827              -0.539827     0.539827
# 이용금액_오프라인_R6M             -0.538775              -0.538775     0.538775
# 정상입금원금_B2M                -0.536208              -0.536208     0.536208
# _3순위업종_이용금액               -0.504268              -0.504268     0.504268
# _2순위업종_이용금액               -0.492209              -0.492209     0.492209
# _2순위쇼핑업종_이용금액             -0.487364              -0.487364     0.487364
# 이용건수_간편결제_R3M             -0.333331              -0.333331     0.333331
# 최대이용금액_할부_무이자_R12M        -0.332958              -0.332958     0.332958
# 최대이용금액_할부_R12M            -0.332917              -0.332917     0.332917
# 이용금액_간편결제_R6M             -0.331895              -0.331895     0.331895
# 이용건수_페이_온라인_R3M           -0.329737              -0.329737     0.329737
# 이용건수_간편결제_B0M             -0.327695              -0.327695     0.327695
# _3순위교통업종_이용금액             -0.327502              -0.327502     0.327502
# 쇼핑_편의점_이용금액               -0.326543              -0.326543     0.326543
# 이용건수_페이_온라인_B0M           -0.324620              -0.324620     0.324620
# 할부금액_무이자_3M_R12M          -0.323400              -0.323400     0.323400
# 이용개월수_온라인_R6M             -0.321242              -0.321242     0.321242
# 이용개월수_페이_온라인_R6M          -0.318474              -0.318474     0.318474
# 납부_기타이용금액                 -0.314270              -0.314270     0.314270
# 이용개월수_간편결제_R6M            -0.313498              -0.313498     0.313498
# 최대이용금액_CA_R12M            -0.306450              -0.306450     0.306450
# _2순위교통업종_없음                     NaN               0.306219     0.306219
# 할부금액_6M_R12M              -0.295831              -0.295831     0.295831
# 쇼핑_기타_이용금액                -0.295248              -0.295248     0.295248
# 이용금액_해외                   -0.294269              -0.294269     0.294269
# 이용개월수_할부_무이자_R12M         -0.293027              -0.293027     0.293027
# 이용금액_할부_무이자_R6M           -0.291934              -0.291934     0.291934
# 이용개월수_할부_R12M             -0.290497              -0.290497     0.290497
# 이용건수_할부_R12M              -0.289500              -0.289500     0.289500
# 이용금액_할부_R6M               -0.289399              -0.289399     0.289399
# _3순위교통업종_없음                     NaN               0.289291     0.289291
# _3순위쇼핑업종_없음                     NaN               0.287443     0.287443
# 이용건수_할부_무이자_R12M          -0.286051              -0.286051     0.286051
# _1순위여유업종_이용금액             -0.285466              -0.285466     0.285466
# 이용금액_CA_R12M              -0.283920              -0.283920     0.283920
# _3순위업종_없음                       NaN               0.282960     0.282960
# 할부건수_3M_R12M              -0.281473              -0.281473     0.281473
# _1순위교통업종_주유                     NaN              -0.280283     0.280283
# 쇼핑_백화점_이용금액               -0.279770              -0.279770     0.279770
# 할부건수_무이자_3M_R12M          -0.279451              -0.279451     0.279451
# 할부금액_무이자_6M_R12M          -0.279384              -0.279384     0.279384
# 이용건수_CA_R12M              -0.278491              -0.278491     0.278491
# 이용금액_CA_R6M               -0.275540              -0.275540     0.275540
# 이용개월수_신용_R12M             -0.275250              -0.275250     0.275250
# _1순위교통업종_없음                     NaN               0.273634     0.273634
# 이용개월수_신판_R12M             -0.272852              -0.272852     0.272852
# 이용개월수_일시불_R12M            -0.271402              -0.271402     0.271402
# _2순위쇼핑업종_없음                     NaN               0.270973     0.270973
# 이용개월수_CA_R12M             -0.270881              -0.270881     0.270881
# 이용금액_CA_R3M               -0.267343              -0.267343     0.267343
# 이용금액_CA_B0M               -0.262731              -0.262731     0.262731
# _1순위여유업종_없음                     NaN               0.261836     0.261836
# 이용건수_할부_R6M               -0.257437              -0.257437     0.257437
# _2순위업종_없음                       NaN               0.256967     0.256967
# 이용후경과월_할부_무이자              0.256619               0.256619     0.256619
# 이용개월수_할부_R6M              -0.255660              -0.255660     0.255660
# 이용금액_할부_무이자_R3M           -0.255172              -0.255172     0.255172
# _1순위쇼핑업종_온라인                    NaN              -0.255103     0.255103
# 이용개월수_할부_무이자_R6M          -0.255036              -0.255036     0.255036
# 이용건수_할부_무이자_R6M           -0.254382              -0.254382     0.254382
# 교통_택시이용금액                 -0.253612              -0.253612     0.253612
# 최종이용일자_할부                 -0.252940              -0.252940     0.252940
# 이용금액_할부_R3M               -0.252239              -0.252239     0.252239
# 이용후경과월_할부                  0.251750               0.251750     0.251750
# 최종이용일자_CA                 -0.251535              -0.251535     0.251535
# _1순위쇼핑업종_없음                     NaN               0.251273     0.251273
# _1순위업종_쇼핑                       NaN              -0.250997     0.250997
# 이용건수_CA_R6M               -0.247865              -0.247865     0.247865
# 여유_운동이용금액                 -0.245944              -0.245944     0.245944
# 이용개월수_CA_R6M              -0.244660              -0.244660     0.244660
# 이용건수_할부_R3M               -0.242694              -0.242694     0.242694
# 이용건수_할부_무이자_R3M           -0.241912              -0.241912     0.241912
# _2순위납부업종_없음                     NaN               0.241405     0.241405
# 이용개월수_할부_R3M              -0.239813              -0.239813     0.239813
# 이용개월수_할부_무이자_R3M          -0.237834              -0.237834     0.237834
# 할부건수_6M_R12M              -0.237502              -0.237502     0.237502
# 이용후경과월_CA                  0.237314               0.237314     0.237314
# 이용건수_할부_B0M               -0.233224              -0.233224     0.233224
# 이용개월수_전체_R6M              -0.232901              -0.232901     0.232901
# 이용개월수_CA_R3M              -0.232772              -0.232772     0.232772
# 이용건수_할부_무이자_B0M           -0.232745              -0.232745     0.232745
# _1순위납부업종_이용금액             -0.230848              -0.230848     0.230848
# 이용금액_할부_무이자_B0M           -0.230810              -0.230810     0.230810
# 이용건수_CA_R3M               -0.230616              -0.230616     0.230616
# 할부건수_무이자_6M_R12M          -0.229298              -0.229298     0.229298
# 이용금액_할부_B0M               -0.227516              -0.227516     0.227516
# _2순위교통업종_정비                     NaN              -0.226775     0.226775
# 이용금액_체크_R12M              -0.225854              -0.225854     0.225854
# 이용건수_CA_B0M               -0.221256              -0.221256     0.221256
# 이용금액_체크_R6M               -0.221042              -0.221042     0.221042
# 이용금액_체크_R3M               -0.217935              -0.217935     0.217935
# 이용개월수_전체_R3M              -0.216554              -0.216554     0.216554
# 이용개월수_오프라인_R6M            -0.216505              -0.216505     0.216505
# 이용건수_체크_R12M              -0.216394              -0.216394     0.216394
# 이용개월수_신용_R6M              -0.215954              -0.215954     0.215954
# 이용금액_체크_B0M               -0.215510              -0.215510     0.215510
# RP건수_B0M                  -0.214941              -0.214941     0.214941
# 최대이용금액_체크_R12M            -0.214223              -0.214223     0.214223
# 이용건수_체크_R6M               -0.211961              -0.211961     0.211961
# _2순위여유업종_이용금액             -0.209964              -0.209964     0.209964
# 이용건수_체크_R3M               -0.209960              -0.209960     0.209960
# 이용개월수_신판_R6M              -0.209428              -0.209428     0.209428
# _3순위쇼핑업종_마트                     NaN              -0.209359     0.209359
# 이용개월수_일시불_R6M             -0.208679              -0.208679     0.208679
# 이용건수_체크_B0M               -0.208544              -0.208544     0.208544
# _1순위여유업종_운동                     NaN              -0.205597     0.205597
# 이용후경과월_신용                  0.204829               0.204829     0.204829
# 이용개월수_신용_R3M              -0.202547              -0.202547     0.202547
# _2순위여유업종_없음                     NaN               0.200328     0.200328
# _2순위납부업종_이용금액             -0.198603              -0.198603     0.198603
# 이용개월수_신판_R3M              -0.196353              -0.196353     0.196353
# 이용개월수_일시불_R3M             -0.195539              -0.195539     0.195539
# 최대이용금액_할부_유이자_R12M        -0.195439              -0.195439     0.195439
# 이용금액_할부_유이자_R12M          -0.194609              -0.194609     0.194609
# 이용후경과월_신판                  0.194259               0.194259     0.194259
# 납부_통신비이용금액                -0.193360              -0.193360     0.193360
# RP유형건수_B0M                -0.191816              -0.191816     0.191816
# _1순위업종_없음                       NaN               0.185706     0.185706
# _1순위납부업종_없음                     NaN               0.184146     0.184146
# 할부금액_유이자_3M_R12M          -0.183528              -0.183528     0.183528
# 교통_철도버스이용금액               -0.181839              -0.181839     0.181839
# 납부_보험료이용금액                -0.181590              -0.181590     0.181590
# RP후경과월_교통                  0.180352               0.180352     0.180352
# RP건수_통신_B0M               -0.178746              -0.178746     0.178746
# _3순위납부업종_없음                     NaN               0.178545     0.178545
# 쇼핑_아울렛_이용금액               -0.177455              -0.177455     0.177455
# 이용후경과월_일시불                 0.176248               0.176248     0.176248
# 이용개월수_할부_유이자_R12M         -0.175693              -0.175693     0.175693
# _2순위업종_사교활동                     NaN              -0.175586     0.175586
# 이용개월수_결제일_R6M             -0.174919              -0.174919     0.174919
# 이용개월수_체크_R12M             -0.173483              -0.173483     0.173483
# 신청건수_ATM_CA_R6M           -0.172142              -0.172142     0.172142
# 할부금액_유이자_6M_R12M          -0.166809              -0.166809     0.166809
# 이용후경과월_할부_유이자              0.166400               0.166400     0.166400
# 연속무실적개월수_기본_24M_카드         0.166218               0.166218     0.166218
# _3순위업종_교통                       NaN              -0.166184     0.166184
# 이용건수_할부_유이자_R12M          -0.166099              -0.166099     0.166099
# 선입금원금_B5M                 -0.164146              -0.164146     0.164146
# 여유_숙박이용금액                 -0.164041              -0.164041     0.164041
# 여유_공연이용금액                 -0.163621              -0.163621     0.163621
# 이용개월수_결제일_R3M             -0.161885              -0.161885     0.161885
# _2순위쇼핑업종_마트                     NaN              -0.160259     0.160259
# 선입금원금_B0M                 -0.159983              -0.159983     0.159983
# 이용개월수_체크_R6M              -0.158393              -0.158393     0.158393
# 할부건수_유이자_3M_R12M          -0.158301              -0.158301     0.158301
# 선입금원금_B2M                 -0.158290              -0.158290     0.158290
# RP건수_교통_B0M               -0.157904              -0.157904     0.157904
# _3순위납부업종_납부기타                   NaN              -0.157733     0.157733
# 최종이용일자_기본                 -0.157172              -0.157172     0.157172
# 최종이용일자_일시불                -0.156726              -0.156726     0.156726
# 이용금액_선결제_R6M              -0.156423              -0.156423     0.156423
# _3순위교통업종_정비                     NaN              -0.156369     0.156369
# 최종이용일자_체크                 -0.156292              -0.156292     0.156292
# RP후경과월_통신                  0.156057               0.156057     0.156057
# 이용개월수_체크_R3M              -0.156024              -0.156024     0.156024
# 카드론이용월수_누적                -0.154625              -0.154625     0.154625
# 최종이용일자_신판                 -0.154610              -0.154610     0.154610
# _2순위납부업종_납부기타                   NaN              -0.153845     0.153845
# 카드론이용건수_누적                -0.152304              -0.152304     0.152304
# 이용후경과월_체크                  0.151309               0.151309     0.151309
# 이용금액_A페이_B0M              -0.150200              -0.150200     0.150200
# 이용금액_페이_오프라인_B0M          -0.150026              -0.150026     0.150026
# 이용금액_A페이_R3M              -0.146013              -0.146013     0.146013
# 이용금액_페이_오프라인_R3M          -0.145967              -0.145967     0.145967
# RP후경과월                     0.145713               0.145713     0.145713
# 이용건수_A페이_R6M              -0.144385              -0.144385     0.144385
# 이용금액_선결제_R3M              -0.144346              -0.144346     0.144346
# RP금액_B0M                  -0.143660              -0.143660     0.143660
# 최종카드론_대출이율                -0.143165              -0.143165     0.143165
# _3순위교통업종_철도버스                   NaN              -0.142542     0.142542
# 이용개월수_페이_오프라인_R6M         -0.142501              -0.142501     0.142501
# 이용횟수_선결제_R6M              -0.142232              -0.142232     0.142232
# 이용금액_A페이_R6M              -0.140690              -0.140690     0.140690
# 이용금액_할부_유이자_R6M           -0.140368              -0.140368     0.140368
# 이용금액_페이_오프라인_R6M          -0.139783              -0.139783     0.139783
# _3순위교통업종_택시                     NaN              -0.139529     0.139529
# 교통_버스지하철이용금액              -0.138894              -0.138894     0.138894
# 신청건수_ATM_CA_B0            -0.138772              -0.138772     0.138772
# 이용개월수_A페이_R6M             -0.137863              -0.137863     0.137863
# 이용건수_페이_오프라인_R6M          -0.137755              -0.137755     0.137755
# 이용건수_A페이_R3M              -0.136760              -0.136760     0.136760
# 이용건수_할부_유이자_R6M           -0.136149              -0.136149     0.136149
# 이용건수_페이_오프라인_B0M          -0.135338              -0.135338     0.135338
# 이용건수_페이_오프라인_R3M          -0.135263              -0.135263     0.135263
# _3순위여유업종_이용금액             -0.134882              -0.134882     0.134882
# 이용개월수_할부_유이자_R6M          -0.133410              -0.133410     0.133410
# 이용금액_선결제_B0M              -0.133080              -0.133080     0.133080
# _3순위여유업종_없음                     NaN               0.132528     0.132528
# 이용금액_C페이_B0M              -0.132142              -0.132142     0.132142
# 이용금액_C페이_R3M              -0.132111              -0.132111     0.132111
# 이용건수_A페이_B0M              -0.131737              -0.131737     0.131737
# 이용건수_C페이_B0M              -0.130739              -0.130739     0.130739
# _3순위납부업종_이용금액             -0.130278              -0.130278     0.130278
# 이용개월수_선결제_R6M             -0.130227              -0.130227     0.130227
# 최초카드론이용경과월                 0.129799               0.129799     0.129799
# 이용횟수_선결제_R3M              -0.128725              -0.128725     0.128725
# 이용금액_C페이_R6M              -0.127859              -0.127859     0.127859
# 이용건수_C페이_R3M              -0.127385              -0.127385     0.127385
# 여유_기타이용금액                 -0.126732              -0.126732     0.126732
# 최종카드론이용경과월                 0.125008               0.125008     0.125008
# 이용개월수_할부_유이자_R3M          -0.121789              -0.121789     0.121789
# 이용건수_선결제_R6M              -0.121656              -0.121656     0.121656
# 할부건수_유이자_6M_R12M          -0.120181              -0.120181     0.120181
# _2순위여유업종_숙박                     NaN              -0.119110     0.119110
# 이용횟수_선결제_B0M              -0.118892              -0.118892     0.118892
# _2순위납부업종_통신비                    NaN              -0.118751     0.118751
# 이용건수_할부_유이자_R3M           -0.117418              -0.117418     0.117418
# 최종이용일자_카드론                -0.117082              -0.117082     0.117082
# _2순위납부업종_보험료                    NaN              -0.116811     0.116811
# 이용금액_할부_유이자_R3M           -0.116652              -0.116652     0.116652
# 이용건수_C페이_R6M              -0.115854              -0.115854     0.115854
# _1순위납부업종_보험료                    NaN              -0.114788     0.114788
# _1순위업종_납부                       NaN               0.113467     0.113467
# 할부금액_12M_R12M             -0.112694              -0.112694     0.112694
# 이용개월수_C페이_R6M             -0.110886              -0.110886     0.110886
# _2순위여유업종_공연                     NaN              -0.110814     0.110814
# 카드론이용금액_누적                -0.109821              -0.109821     0.109821
# _1순위납부업종_통신비                    NaN              -0.107479     0.107479
# 할부금액_무이자_12M_R12M         -0.106619              -0.106619     0.106619
# 이용건수_할부_유이자_B0M           -0.103928              -0.103928     0.103928
# 이용금액_D페이_R6M              -0.102419              -0.102419     0.102419
# _3순위쇼핑업종_슈퍼마켓                   NaN              -0.102254     0.102254
# 이용건수_선결제_R3M              -0.100796              -0.100796     0.100796
# 최종카드론_금융상환방식코드                  NaN              -0.099351     0.099351
# 최종카드론_대출월수                -0.098526              -0.098526     0.098526
# 이용금액_할부_유이자_B0M           -0.098227              -0.098227     0.098227
# 이용개월수_D페이_R6M             -0.097115              -0.097115     0.097115
# 이용금액_B페이_R6M              -0.096908              -0.096908     0.096908
# 이용건수_B페이_R3M              -0.095738              -0.095738     0.095738
# 이용금액_B페이_R3M              -0.095534              -0.095534     0.095534
# _3순위업종_납부                       NaN              -0.093561     0.093561
# _1순위여유업종_숙박                     NaN              -0.092856     0.092856
# 여유_Pet이용금액                -0.091433              -0.091433     0.091433
# 최종카드론_대출금액                -0.090227              -0.090227     0.090227
# 이용건수_B페이_B0M              -0.089259              -0.089259     0.089259
# _3순위여유업종_공연                     NaN              -0.088704     0.088704
# 이용금액_B페이_B0M              -0.088632              -0.088632     0.088632
# _2순위여유업종_여유기타                   NaN              -0.087804     0.087804
# _3순위업종_의료                       NaN              -0.087612     0.087612
# _2순위교통업종_철도버스                   NaN              -0.086462     0.086462
# 이용건수_D페이_R6M              -0.086461              -0.086461     0.086461
# 여유_항공이용금액                 -0.086369              -0.086369     0.086369
# 이용건수_B페이_R6M              -0.085561              -0.085561     0.085561
# _1순위여유업종_항공                     NaN              -0.084175     0.084175
# RP건수_아파트_B0M              -0.081516              -0.081516     0.081516
# RP후경과월_아파트                 0.081488               0.081488     0.081488
# 이용개월수_B페이_R6M             -0.081422              -0.081422     0.081422
# 납부_관리비이용금액                -0.080332              -0.080332     0.080332
# _1순위납부업종_관리비                    NaN              -0.080033     0.080033
# 이용건수_선결제_B0M              -0.079685              -0.079685     0.079685
# _3순위업종_사교활동                     NaN              -0.076290     0.076290
# 승인거절건수_R3M                -0.075772              -0.075772     0.075772
# 이용금액_연체_R6M               -0.075656              -0.075656     0.075656
# 금액_할부전환_R6M               -0.075245              -0.075245     0.075245
# _1순위여유업종_공연                     NaN              -0.074494     0.074494
# 건수_할부전환_R6M               -0.074299              -0.074299     0.074299
# 금액_할부전환_R3M               -0.074282              -0.074282     0.074282
# 건수_할부전환_R3M               -0.074077              -0.074077     0.074077
# 이용금액_D페이_R3M              -0.072966              -0.072966     0.072966
# 여유_공원이용금액                 -0.072424              -0.072424     0.072424
# 최종카드론_신청경로코드_7                  NaN              -0.071663     0.071663
# 할부금액_유이자_12M_R12M         -0.070547              -0.070547     0.070547
# _3순위여유업종_여유기타                   NaN              -0.069128     0.069128
# 납부_가스전기료이용금액              -0.068985              -0.068985     0.068985
# 이용개월수_당사기타_R6M            -0.068789              -0.068789     0.068789
# 할부건수_12M_R12M             -0.067000              -0.067000     0.067000
# 최종카드론_신청경로코드_D                  NaN              -0.065643     0.065643
# 최종카드론_신청경로코드_2                  NaN              -0.065445     0.065445
# _2순위여유업종_운동                     NaN              -0.064651     0.064651
# 최대이용금액_부분무이자_R12M         -0.062817              -0.062817     0.062817
# 최종카드론_신청경로코드_8                  NaN              -0.062800     0.062800
# 이용건수_D페이_R3M              -0.062728              -0.062728     0.062728
# _2순위업종_의료                       NaN              -0.062622     0.062622
# 이용개월수_부분무이자_R12M          -0.062600              -0.062600     0.062600
# 승인거절건수_기타_R3M             -0.062148              -0.062148     0.062148
# 할부금액_부분_12M_R12M          -0.061985              -0.061985     0.061985
# 이용금액_부분무이자_R12M           -0.061763              -0.061763     0.061763
# 이용건수_카드론_R12M             -0.060868              -0.060868     0.060868
# 이용금액_연체_R3M               -0.059830              -0.059830     0.059830
# 이용후경과월_부분무이자               0.058131               0.058131     0.058131
# 이용개월수_카드론_R12M            -0.054858              -0.054858     0.054858
# _1순위업종_교통                       NaN               0.054470     0.054470
# _3순위업종_해외                       NaN              -0.053944     0.053944
# _1순위여유업종_여유기타                   NaN              -0.052559     0.052559
# 할부건수_무이자_12M_R12M         -0.052485              -0.052485     0.052485
# 이용횟수_연체_R6M               -0.051584              -0.051584     0.051584
# 최종카드론_신청경로코드_1                  NaN              -0.051217     0.051217
# 승인거절건수_BL_R3M             -0.050804              -0.050804     0.050804
# _2순위교통업종_택시                     NaN              -0.049131     0.049131
# _3순위납부업종_보험료                    NaN              -0.048962     0.048962
# _3순위여유업종_숙박                     NaN              -0.048840     0.048840
# _2순위업종_납부                       NaN              -0.047228     0.047228
# 이용금액_부분무이자_R3M            -0.046642              -0.046642     0.046642
# _1순위업종_사교활동                     NaN              -0.045884     0.045884
# _2순위쇼핑업종_온라인                    NaN              -0.045148     0.045148
# 이용후경과월_카드론                 0.045075               0.045075     0.045075
# 할부건수_유이자_12M_R12M         -0.044294              -0.044294     0.044294
# 이용금액_연체_B0M               -0.042823              -0.042823     0.042823
# 이용금액_D페이_B0M              -0.041977              -0.041977     0.041977
# 승인거절건수_한도초과_R3M           -0.041426              -0.041426     0.041426
# _3순위여유업종_공원                     NaN              -0.041193     0.041193
# _2순위여유업종_공원                     NaN              -0.040662     0.040662
# 이용건수_D페이_B0M              -0.039843              -0.039843     0.039843
# _3순위납부업종_통신비                    NaN              -0.039471     0.039471
# 이용금액_카드론_R12M             -0.039352              -0.039352     0.039352
# _3순위쇼핑업종_온라인                    NaN              -0.038836     0.038836
# 이용횟수_연체_R3M               -0.038601              -0.038601     0.038601
# _3순위쇼핑업종_백화점                    NaN              -0.038267     0.038267
# RP후경과월_가스                  0.037536               0.037536     0.037536
# 가맹점매출금액_B1M               -0.034953              -0.034953     0.034953
# 가맹점매출금액_B2M               -0.034526              -0.034526     0.034526
# _3순위쇼핑업종_편의점                    NaN              -0.033606     0.033606
# 최대이용금액_카드론_R12M           -0.032602              -0.032602     0.032602
# RP후경과월_전기                  0.032019               0.032019     0.032019
# 이용개월수_카드론_R6M             -0.030776              -0.030776     0.030776
# _1순위쇼핑업종_슈퍼마켓                   NaN               0.030622     0.030622
# RP건수_가스_B0M               -0.030050              -0.030050     0.030050
# RP후경과월_보험                  0.028738               0.028738     0.028738
# 이용금액_부분무이자_R6M            -0.028402              -0.028402     0.028402
# 이용횟수_연체_B0M               -0.027847              -0.027847     0.027847
# 이용건수_카드론_R6M              -0.027271              -0.027271     0.027271
# 최종카드론_대출일자                -0.026679              -0.026679     0.026679
# _1순위여유업종_공원                     NaN              -0.026567     0.026567
# _2순위업종_교통                       NaN              -0.026531     0.026531
# _1순위쇼핑업종_마트                     NaN               0.026100     0.026100
# 이용금액_카드론_R6M              -0.025323              -0.025323     0.025323
# 이용개월수_부분무이자_R6M           -0.024698              -0.024698     0.024698
# RP건수_전기_B0M               -0.023672              -0.023672     0.023672
# _2순위쇼핑업종_편의점                    NaN              -0.023513     0.023513
# _1순위교통업종_정비                     NaN              -0.022961     0.022961
# RP건수_보험_B0M               -0.022558              -0.022558     0.022558
# 이용건수_부분무이자_R6M            -0.021964              -0.021964     0.021964
# 증감_RP유형건수_전월              -0.021910              -0.021910     0.021910
# _2순위쇼핑업종_슈퍼마켓                   NaN              -0.018381     0.018381
# 최종카드론_거치개월수               -0.017839              -0.017839     0.017839
# _1순위업종_의료                       NaN              -0.017602     0.017602
# _2순위업종_해외                       NaN              -0.017589     0.017589
# _2순위쇼핑업종_쇼핑기타                   NaN               0.017041     0.017041
# _1순위교통업종_철도버스                   NaN              -0.015705     0.015705
# RP후경과월_제휴사서비스직접판매         -0.015662              -0.015662     0.015662
# _1순위쇼핑업종_백화점                    NaN               0.015521     0.015521
# 할부금액_14M_R12M              0.015489               0.015489     0.015489
# RP건수_제휴사서비스직접판매_B0M        0.014576               0.014576     0.014576
# _1순위쇼핑업종_쇼핑기타                   NaN               0.014555     0.014555
# 할부금액_유이자_14M_R12M          0.013086               0.013086     0.013086
# _3순위업종_일상생활                     NaN               0.013066     0.013066
# 증감_RP건수_교통_전월             -0.012849              -0.012849     0.012849
# _2순위납부업종_관리비                    NaN              -0.011250     0.011250
# 이용개월수_카드론_R3M             -0.011109              -0.011109     0.011109
# 이용금액_카드론_R3M              -0.010491              -0.010491     0.010491
# _3순위쇼핑업종_쇼핑기타                   NaN               0.010415     0.010415
# _3순위업종_쇼핑                       NaN               0.010407     0.010407
# 이용건수_카드론_R3M              -0.010297              -0.010297     0.010297
# 증감_RP건수_전월                -0.010252              -0.010252     0.010252
# _2순위업종_여유생활                     NaN               0.009158     0.009158
# _1순위업종_해외                       NaN               0.009043     0.009043
# 할부금액_무이자_14M_R12M          0.008688               0.008688     0.008688
# _2순위쇼핑업종_아울렛                    NaN               0.008416     0.008416
# _1순위업종_여유생활                     NaN               0.008198     0.008198
# _1순위쇼핑업종_아울렛                    NaN               0.008001     0.008001
# 할부건수_부분_12M_R12M          -0.007991              -0.007991     0.007991
# 이용건수_부분무이자_R12M           -0.007991              -0.007991     0.007991
# _2순위교통업종_주유                     NaN              -0.007970     0.007970
# _2순위업종_일상생활                     NaN               0.007745     0.007745
# _3순위쇼핑업종_아울렛                    NaN               0.007660     0.007660
# 이용개월수_부분무이자_R3M           -0.007608              -0.007608     0.007608
# 승인거절건수_BL_B0M             -0.006942              -0.006942     0.006942
# 이용건수_부분무이자_R3M            -0.006911              -0.006911     0.006911
# 승인거절건수_입력오류_R3M           -0.006499              -0.006499     0.006499
# 교통_통행료이용금액                -0.006401              -0.006401     0.006401
# _2순위쇼핑업종_백화점                    NaN               0.005435     0.005435
# _2순위업종_쇼핑                       NaN               0.005150     0.005150
# _1순위교통업종_택시                     NaN              -0.004808     0.004808
# 증감_RP건수_아파트_전월             0.004700               0.004700     0.004700
# 증감_RP건수_전기_전월             -0.004202              -0.004202     0.004202
# 증감_RP건수_제휴사서비스직접판매_전월      0.003904               0.003904     0.003904
# _1순위업종_일상생활                     NaN               0.003811     0.003811
# 신청건수_ATM_CL_R6M           -0.003667              -0.003667     0.003667
# _1순위쇼핑업종_편의점                    NaN               0.003644     0.003644
# _3순위업종_여유생활                     NaN              -0.003560     0.003560
# 할부건수_유이자_14M_R12M         -0.003506              -0.003506     0.003506
# _1순위납부업종_납부기타                   NaN              -0.003486     0.003486
# 승인거절건수_B0M                -0.003440              -0.003440     0.003440
# 할부건수_14M_R12M             -0.003439              -0.003439     0.003439
# _3순위업종_요식                       NaN               0.003432     0.003432
# RP건수_렌탈_B0M                0.003063               0.003063     0.003063
# 승인거절건수_한도초과_B0M           -0.002331              -0.002331     0.002331
# _2순위여유업종_항공                     NaN              -0.002055     0.002055
# 신청건수_ATM_CL_B0            -0.002055              -0.002055     0.002055
# 증감_RP건수_통신_전월             -0.001979              -0.001979     0.001979
# RP후경과월_학습비                -0.001949              -0.001949     0.001949
# 증감_RP건수_보험_전월             -0.001901              -0.001901     0.001901
# _2순위업종_요식                       NaN               0.001746     0.001746
# RP건수_학습비_B0M               0.001704               0.001704     0.001704
# RP후경과월_렌탈                  0.001687               0.001687     0.001687
# 이용금액_카드론_B0M               0.001504               0.001504     0.001504
# 증감_RP건수_학습비_전월             0.001210               0.001210     0.001210
# 이용건수_카드론_B0M               0.001172               0.001172     0.001172
# _2순위교통업종_통행료                    NaN              -0.000971     0.000971
# _3순위여유업종_운동                     NaN              -0.000878     0.000878
# 할부금액_부분_6M_R12M           -0.000878              -0.000878     0.000878
# _1순위업종_요식                       NaN               0.000790     0.000790
# _3순위교통업종_통행료                    NaN              -0.000770     0.000770
# 증감_RP건수_렌탈_전월             -0.000575              -0.000575     0.000575
# 할부건수_무이자_14M_R12M          0.000517               0.000517     0.000517
# 증감_RP건수_가스_전월              0.000465               0.000465     0.000465
# 할부금액_부분_14M_R12M           0.000063               0.000063     0.000063
# RP건수_건강_B0M                     NaN                    NaN          NaN
# RP건수_유선방송_B0M                   NaN                    NaN          NaN
# RP후경과월_건강                       NaN                    NaN          NaN
# RP후경과월_유선방송                     NaN                    NaN          NaN
# 납부_건강연금이용금액                     NaN                    NaN          NaN
# 납부_렌탈료이용금액                      NaN                    NaN          NaN
# 납부_유선방송이용금액                     NaN                    NaN          NaN
# 승인거절건수_기타_B0M                   NaN                    NaN          NaN
# 승인거절건수_입력오류_B0M                 NaN                    NaN          NaN
# 여유_여행이용금액                       NaN                    NaN          NaN
# 이용개월수_당사페이_R6M                  NaN                    NaN          NaN
# 이용건수_당사기타_B0M                   NaN                    NaN          NaN
# 이용건수_당사기타_R3M                   NaN                    NaN          NaN
# 이용건수_당사기타_R6M                   NaN                    NaN          NaN
# 이용건수_당사페이_B0M                   NaN                    NaN          NaN
# 이용건수_당사페이_R3M                   NaN                    NaN          NaN
# 이용건수_당사페이_R6M                   NaN                    NaN          NaN
# 이용건수_부분무이자_B0M                  NaN                    NaN          NaN
# 이용금액_당사기타_B0M                   NaN                    NaN          NaN
# 이용금액_당사기타_R3M                   NaN                    NaN          NaN
# 이용금액_당사기타_R6M                   NaN                    NaN          NaN
# 이용금액_당사페이_B0M                   NaN                    NaN          NaN
# 이용금액_당사페이_R3M                   NaN                    NaN          NaN
# 이용금액_당사페이_R6M                   NaN                    NaN          NaN
# 이용금액_부분무이자_B0M                  NaN                    NaN          NaN
# 증감_RP건수_건강_전월                   NaN                    NaN          NaN
# 증감_RP건수_유선방송_전월                 NaN                    NaN          NaN
# 할부건수_부분_14M_R12M                NaN                    NaN          NaN
# 할부건수_부분_3M_R12M                 NaN                    NaN          NaN
# 할부건수_부분_6M_R12M                 NaN                    NaN          NaN
# 할부금액_부분_3M_R12M                 NaN                    NaN          NaN

# %%
# 1. 상관계수 0.1 이상인 칼럼 이름 추출
high_corr_cols = combined_corr[combined_corr['최대상관계수(절댓값)'] >= 0.1].index

# 2. 원본 train_df의 컬럼 목록
original_cols = set(train_df.columns)

# 3. 원본 컬럼 중 상관관계 높은 컬럼만 추출
high_corr_original_cols = [col for col in high_corr_cols if col in original_cols]

# 결과 출력
print("✅ 인코딩 전 원본 컬럼 중 Segment와 상관관계가 0.1 이상인 변수 개수:", len(high_corr_original_cols))
print(high_corr_original_cols)
# Out:
# ✅ 인코딩 전 원본 컬럼 중 Segment와 상관관계가 0.1 이상인 변수 개수: 245
        '이용후경과월_신판', '납부_통신비이용금액', 'RP유형건수_B0M', '할부금액_유이자_3M_R12M', '교통_철도버스이용금액', '납부_보험료이용금액', 
        'RP후경과월_교통', 'RP건수_통신_B0M', '쇼핑_아울렛_이용금액', '이용후경과월_일시불', '이용개월수_할부_유이자_R12M', '이용개월수_결제일_R6M', 
        '이용개월수_체크_R12M', '신청건수_ATM_CA_R6M', '할부금액_유이자_6M_R12M', '이용후경과월_할부_유이자', '연속무실적개월수_기본_24M_카드', 
        '이용건수_할부_유이자_R12M', '선입금원금_B5M', '여유_숙박이용금액', '여유_공연이용금액', '이용개월수_결제일_R3M', '선입금원금_B0M', 
        '이용개월수_체크_R6M', '할부건수_유이자_3M_R12M', '선입금원금_B2M', 'RP건수_교통_B0M', '최종이용일자_기본', '최종이용일자_일시불', 
        '이용금액_선결제_R6M', '최종이용일자_체크', 'RP후경과월_통신', '이용개월수_체크_R3M', '카드론이용월수_누적', '최종이용일자_신판', 
        '카드론이용건수_누적', '이용후경과월_체크', '이용금액_A페이_B0M', '이용금액_페이_오프라인_B0M', '이용금액_A페이_R3M', '이용금액_페이_오프라인_R3M', 
        'RP후경과월', '이용건수_A페이_R6M', '이용금액_선결제_R3M', 'RP금액_B0M', '최종카드론_대출이율', '이용개월수_페이_오프라인_R6M', '이용횟수_선결제_R6M', 
        '이용금액_A페이_R6M', '이용금액_할부_유이자_R6M', '이용금액_페이_오프라인_R6M', '교통_버스지하철이용금액', '신청건수_ATM_CA_B0', '이용개월수_A페이_R6M', 
        '이용건수_페이_오프라인_R6M', '이용건수_A페이_R3M', '이용건수_할부_유이자_R6M', '이용건수_페이_오프라인_B0M', '이용건수_페이_오프라인_R3M', 
        '_3순위여유업종_이용금액', '이용개월수_할부_유이자_R6M', '이용금액_선결제_B0M', '이용금액_C페이_B0M', '이용금액_C페이_R3M', '이용건수_A페이_B0M', 
        '이용건수_C페이_B0M', '_3순위납부업종_이용금액', '이용개월수_선결제_R6M', '최초카드론이용경과월', '이용횟수_선결제_R3M', '이용금액_C페이_R6M', 
        '이용건수_C페이_R3M', '여유_기타이용금액', '최종카드론이용경과월', '이용개월수_할부_유이자_R3M', '이용건수_선결제_R6M', '할부건수_유이자_6M_R12M', 
        '이용횟수_선결제_B0M', '이용건수_할부_유이자_R3M', '최종이용일자_카드론', '이용금액_할부_유이자_R3M', '이용건수_C페이_R6M', '할부금액_12M_R12M', 
        '이용개월수_C페이_R6M', '카드론이용금액_누적', '할부금액_무이자_12M_R12M', '이용건수_할부_유이자_B0M', '이용금액_D페이_R6M', '이용건수_선결제_R3M',
    '청구금액_B0',
 '청구금액_R3M',
 '청구금액_R6M',
 '포인트_마일리지_건별_B0M',
 '포인트_마일리지_건별_R3M',
 '포인트_포인트_건별_B0M',
 '포인트_포인트_건별_R3M',
 '포인트_마일리지_월적립_B0M',
 '포인트_마일리지_월적립_R3M',
 '포인트_포인트_월적립_B0M',
 '포인트_포인트_월적립_R3M',
 '포인트_적립포인트_R12M',
 '포인트_적립포인트_R3M',
 '포인트_이용포인트_R12M',
 '포인트_이용포인트_R3M',
 '마일_적립포인트_R12M',
 '마일_적립포인트_R3M',
 '마일_이용포인트_R12M',
 '마일_이용포인트_R3M',
 '마일_잔여포인트_B0M',
 '할인금액_R3M',
 '할인금액_B0M',
 '할인금액_청구서_R3M',
 '할인금액_청구서_B0M',
 '상환개월수_결제일_R6M',
 '상환개월수_결제일_R3M',
 '선결제건수_R6M',
 '선결제건수_R3M',
 '혜택수혜금액_R3M',
 '포인트_마일리지_환산_B0M',
 '혜택수혜금액',
 '잔액_일시불_B0M',
 '잔액_할부_B0M',
 '잔액_현금서비스_B0M',
 '월중평잔_일시불_B0M',
 '월중평잔_할부_B0M',
 '월중평잔_CA_B0M',
 '잔액_현금서비스_B1M',
 '잔액_현금서비스_B2M',
 '잔액_할부_B1M',
 '잔액_할부_B2M',
 '잔액_일시불_B1M',
 '잔액_일시불_B2M',
 '잔액_할부_유이자_B0M',
 '잔액_할부_무이자_B0M',
 '월중평잔',
 '월중평잔_일시불',
 '월중평잔_RV일시불',
 '월중평잔_할부',
 '월중평잔_CA',
 '평잔_3M',
 '평잔_일시불_3M',
 '평잔_일시불_해외_3M',
 '평잔_RV일시불_3M',
 '평잔_RV일시불_해외_3M',
 '평잔_할부_3M',
 '평잔_CA_3M',
 '평잔_6M',
 '평잔_일시불_6M',
 '평잔_일시불_해외_6M',
 '평잔_RV일시불_6M',
 '평잔_RV일시불_해외_6M',
 '평잔_할부_6M',
 '평잔_CA_6M',
 '인입횟수_ARS_R6M',
 '인입일수_ARS_R6M',
 '인입월수_ARS_R6M',
 '인입횟수_ARS_B0M',
 '이용메뉴건수_ARS_B0M',
 '인입일수_ARS_B0M',
 '방문월수_PC_R6M',
 '방문후경과월_PC_R6M',
 '방문횟수_앱_R6M',
 '방문일수_앱_R6M',
 '방문월수_앱_R6M',
 '방문후경과월_앱_R6M',
 '방문횟수_PC_B0M',
 '방문일수_PC_B0M',
 '방문횟수_앱_B0M',
 '방문일수_앱_B0M',
 '인입횟수_IB_R6M',
 '인입일수_IB_R6M',
 '인입월수_IB_R6M',
 '이용메뉴건수_IB_R6M',
 '인입후경과월_IB_R6M',
 '상담건수_R6M',
 'IB문의건수_사용승인내역_R6M',
 'IB문의건수_선결제_R6M',
 '불만제기후경과월_R12M',
 '당사멤버쉽_방문월수_R6M',
 '홈페이지_금융건수_R6M',
 '홈페이지_선결제건수_R6M',
 '홈페이지_금융건수_R3M',
 '홈페이지_선결제건수_R3M',
 'OS구분코드',
 '청구서발송여부_B0',
 '청구서발송여부_R3M',
 '청구서발송여부_R6M',
        '컨택건수_이용유도_TM_R6M',
    '변동률_RVCA평잔',
    '변동률_RV일시불평잔',
    '컨택건수_이용유도_EM_B0M',
    '컨택건수_이용유도_EM_R6M',
    '잔액_신판평균한도소진율_r6m',
    '잔액_신판평균한도소진율_r3m',
    '잔액_신판최대한도소진율_r3m',
    '잔액_신판최대한도소진율_r6m',
    '잔액_신판ca평균한도소진율_r6m',
    '잔액_신판ca평균한도소진율_r3m',
    '잔액_신판ca최대한도소진율_r3m',
    '잔액_신판ca최대한도소진율_r6m']

# %%
print(len(cols))
# Out:
# 396
